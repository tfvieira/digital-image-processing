# %% [markdown]
# # Digital Image Processing

# %% [markdown]
# ## Crop Images

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from utils import *
path = '../img/'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams["figure.dpi"] = 100

# %%
path = '../img/'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams["figure.dpi"] = 100

# %%
print(f'Using {cv2.__name__} version {cv2.__version__}')
# Out:
# Using cv2 version 4.8.0

# %%
image = cv2.imread(os.path.join(path, 'lena.png'))
height, width = image.shape[:2]

# %% [markdown]
# Lets get starting pixel coordinates (top left of cropping rectangle)

# %%
start_row, start_col = int(height * .25), int(width * .25)

# %% [markdown]
# Lets get the ending pixel coordinates (bottom right)

# %%
end_row, end_col = int(height * .75), int(height * .75)

# %% [markdown]
# Simply use indexing to crop out the rectangle we desire

# %%
cropped = image[start_row:end_row, start_col:end_col]

# %%
plt.figure(figsize=(16,8))
plt.subplot(121), plt.imshow(bgr2rgb(image  ))
plt.subplot(122), plt.imshow(bgr2rgb(cropped))
plt.show()
