# %% [markdown]
# # Task Chroma-Keying

# %% [markdown]
# 1. Remove the _background_ from image ```avengers.png```.
# 1. Insert another image in the background.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
imfile = '../../../img/avengers.png'
bgr = cv2.imread(imfile)
rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb)
plt.axis(False)
plt.show()

# %% [markdown]
# ## Solution 1

# %%
# TODO

# %% [markdown]
# ## Solution 2

# %%
# TODO
