# %% [markdown]
# # Task HSV Disk

# %% [markdown]
# Develop the code that generates the image of an HSV disk of size $500\times 500$, as shown below.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
imfile = '../../../img/hsv_disk.png'
hsv_disk = cv2.imread(imfile)

# %%
plt.imshow(hsv_disk)
